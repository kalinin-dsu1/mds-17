# %% [markdown]
# # Уровень 0:

# %% [markdown]
# ## Задание 1:
#
# Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа орлов.

# %%
import math

p = 0
for k in [2,3,5,7,11,13]:
    p += math.factorial(15) / (math.factorial(k) * math.factorial(15 - k)) * 0.5 ** 15

print('Вероятность выпадения простого числа орлов: ', p)
# Out:
# Вероятность выпадения простого числа орлов:  0.3499755859375

# %% [markdown]
# ## Задание 2:
#
# Создайте свою дискретную случайную величину с не менее, чем 10 значениями. Просемплируйте 1000 случайных значений, постройте гистограмму плотности распределения по выборке, посчитайте среднее, дисперсию и медиану.

# %%
import numpy as np
import matplotlib.pyplot as plt

def dice_throw():
    return np.random.randint(1,7) + np.random.randint(1,7)

result = []
for i in range(0, 1000):
    result.append(dice_throw())


plt.hist(result)
plt.show()

# %%
print('Медиана: ', np.median(result))
print('Дисперсия: ', np.var(result))
print('Среднее: ', np.mean(result))
# Out:
# Медиана:  7.0
# Дисперсия:  5.9204
# Среднее:  6.84

# %% [markdown]
# # Уровень 1:

# %% [markdown]
# ## Задание 3:
#
# Пусть брошены 3 уравновешенные монеты.
#
# Рассмотрим 3 события:
#
# A1 - монеты 1 и 2 упали одной и той же стороной;
#
# A2 - монеты 2 и 3 упали одной и той же стороной;
#
# A3 - монеты 1 и 3 упали одной и той же стороной.
#
# Покажите, почему эти 3 события (A1, A2, A3) являются попарно независимыми, но не являются независимыми в совокупности.

# %% [markdown]
# ### Решение:
#
# **Попарная независимость:**
#
# $p(A_1) = p(A_2) = p(A_3) = 0.5$
#
# $p(A_i \cap A_j) = 0.25$
#
# $p(A_i) * p(A_j) = 0.5 * 0.5 = 0.25$
#
# Следовательно
#
# $p(A_i \cap A_j) = p(A_i) * p(A_j)$
#
# и события попарно независимы
#
# **Совокупная зависимость:**
#
# $p(A_1 \cap A_2 \cap A_3) = 0.25$
#
# $p(A_1) * p(A_2) * p(A_3) = 0.5 * 0.5 * 0.5 = 0.125$
#
# Следовательно
#
# $p(A1 \cap A2 \cap A3) \neq p(A1) * p(A2) * p(A3)$
#
# и события совокупно зависимы

# %% [markdown]
# ## Задание 4 (формула полной вероятности):
# В магазин привезли устройства с 3-х разных предприятий.
#
# Соотношение устройств следующее: 20% - продукция первого предприятия, 30% - продукция второго предприятия, 50% - продукция третьего предприятия; далее, 10% продукции первого предприятия высшего сорта, на втором предприятии - 5% и на третьем - 20% продукции высшего сорта.
#
# Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %% [markdown]
# ### Решение:
#
# Определим события:
# * $A$ - куплена продукция высшего сорта
# * $B_1$ - куплена продукция первого предприятия, p(A1) = 0.2
# * $B_2$ - куплена продукция второго предприятия, p(A1) = 0.3
# * $B_3$ - куплена продукция третьего предприятия, p(A1) = 0.5
#
# Тогда
# * вероятность купить продукцию высшего сорта на первом предприятии $p(A|B_1) = 0.1$
# * вероятность купить продукцию высшего сорта на втором предприятии $p(A|B_2) = 0.05$
# * вероятность купить продукцию высшего сорта на третьем предприятии $p(A|B_3) = 0.2$
#
# Так как события $B_1$, $B_2$, $B_3$ попарно несовместимы, а их объединение образует пространство элементарных исходов, то:
#
# $p(A) = p(A|B_1)*p(B_1) + p(A|B_2)*p(B_2) + p(A|B_3)*p(B_3) = 0.1*0.2 + 0.05*0.3 + 0.2*0.5 = 0.02 + 0.015 + 0.1 = 0.135$
